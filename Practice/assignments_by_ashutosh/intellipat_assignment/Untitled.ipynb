# %%
import pandas as pd

# %%
ins=pd.read_csv("insurance (3).csv")

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
ins.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
for key,value in ins.iteritems():
    print(key,value[0],sep="\n")
# Out:
# age
# 19
# sex
# female
# bmi
# 27.9
# children
# 0
# smoker
# yes
# region
# southwest
# charges
# 16884.924

# %%
ins.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
rows=ins.shape[0]
cols=ins.shape[1]

# %%
print("rows =",rows)
print("columns =",cols)
# Out:
# rows = 1338
# columns = 7

# %%
ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import matplotlib.pyplot as plt
import numpy as np
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
binx=np.arange(0,101,20)

ax.hist(ins['age'],binx,facecolor="g",alpha=0.5)
ax.set_xticks(np.arange(0,101,20))

# %%
ins.sort_values(by='age',ascending=False)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 335    64    male  34.500         0     no  southwest  13822.80300
# 603    64  female  39.050         3     no  southeast  16085.12750
# 752    64    male  37.905         0     no  northwest  14210.53595
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 534    64    male  40.480         0     no  southeast  13831.11520
# ...   ...     ...     ...       ...    ...        ...          ...
# 942    18  female  40.185         0     no  northeast   2217.46915
# 46     18  female  38.665         2     no  northeast   3393.35635
# 295    18    male  22.990         0     no  northeast   1704.56810
# 50     18  female  35.625         0     no  northeast   2211.13075
# 648    18    male  28.500         0     no  northeast   1712.22700
#
# [1338 rows x 7 columns]

# %%
ins[500:1001]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 500    29    male  34.400         0    yes  southwest  36197.69900
# 501    43    male  26.030         0     no  northeast   6837.36870
# 502    51    male  23.210         1    yes  southeast  22218.11490
# 503    19    male  30.250         0    yes  southeast  32548.34050
# 504    38  female  28.930         1     no  southeast   5974.38470
# ...   ...     ...     ...       ...    ...        ...          ...
# 996    39  female  34.100         3     no  southwest   7418.52200
# 997    63  female  36.850         0     no  southeast  13887.96850
# 998    33  female  36.290         3     no  northeast   6551.75010
# 999    36  female  26.885         0     no  northwest   5267.81815
# 1000   30    male  22.990         2    yes  northwest  17361.76610
#
# [501 rows x 7 columns]

# %%
insurance_random_set=pd.DataFrame({'age':ins['age']})
insurance_random_set['children']=ins['children']
insurance_random_set['sex']=ins['sex']

# %%
insurance_random_set
# Out:
#       age  children     sex
# 0      19         0  female
# 1      18         1    male
# 2      28         3    male
# 3      33         0    male
# 4      32         0    male
# ...   ...       ...     ...
# 1333   50         3    male
# 1334   18         0  female
# 1335   18         0  female
# 1336   21         0  female
# 1337   61         0  female
#
# [1338 rows x 3 columns]

# %%
insurance_random_set=ins.loc[500:1000,['age','sex','children']]

# %%
insurance_random_set
# Out:
#       age     sex  children
# 500    29    male         0
# 501    43    male         0
# 502    51    male         1
# 503    19    male         0
# 504    38  female         1
# ...   ...     ...       ...
# 996    39  female         3
# 997    63  female         0
# 998    33  female         3
# 999    36  female         0
# 1000   30    male         2
#
# [501 rows x 3 columns]

# %%
insurance_random_set=ins.iloc[500:1001,[0,1,3]]

# %%
insurance_random_set
# Out:
#       age     sex  children
# 500    29    male         0
# 501    43    male         0
# 502    51    male         1
# 503    19    male         0
# 504    38  female         1
# ...   ...     ...       ...
# 996    39  female         3
# 997    63  female         0
# 998    33  female         3
# 999    36  female         0
# 1000   30    male         2
#
# [501 rows x 3 columns]

# %%
year=int(input("enter year "))
if(  ( year%4==0 and year%100!=0) or ( year%100==0 and year%400==0) or (year%400==0)):
 print("Leap Year")
else:
 print("NoN Leap Year")
# Out:
# enter year2016
# Leap Year

# %%
ins.rename(columns={'bmi': 'Body Mass Index','region':'Region'})
# Out:
#       age     sex  Body Mass Index  children smoker     Region      charges
# 0      19  female           27.900         0    yes  southwest  16884.92400
# 1      18    male           33.770         1     no  southeast   1725.55230
# 2      28    male           33.000         3     no  southeast   4449.46200
# 3      33    male           22.705         0     no  northwest  21984.47061
# 4      32    male           28.880         0     no  northwest   3866.85520
# ...   ...     ...              ...       ...    ...        ...          ...
# 1333   50    male           30.970         3     no  northwest  10600.54830
# 1334   18  female           31.920         0     no  northeast   2205.98080
# 1335   18  female           36.850         0     no  southeast   1629.83350
# 1336   21  female           25.800         0     no  southwest   2007.94500
# 1337   61  female           29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
ins[['age','bmi','children']].corr()
# Out:
#                age       bmi  children
# age       1.000000  0.109272  0.042469
# bmi       0.109272  1.000000  0.012759
# children  0.042469  0.012759  1.000000
